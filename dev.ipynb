# %%
import os
import dotenv
from todoist_api_python.api import TodoistAPI
from notion_client import Client

dotenv.load_dotenv()

todoist_token = os.getenv("TODOIST_TOKEN")
notion_token = os.getenv("NOTION_TOKEN")

todoist = TodoistAPI(todoist_token)

notion = Client(auth=notion_token)

# %%
print("""
{'model': {'messages': [AIMessage(content='Based on your **Todoist tasks**, **Notion notes**, and **job-seeking progress**, here are the **next prioritized steps** for your move and job search in Norway:\n\n---\n\n### **1. Immediate Priorities (1-2 Weeks)**\n#### **A. Personal Branding & Visibility (Critical for Job Search)**\n- **Complete LinkedIn optimization**:\n  - List all skills on LinkedIn (task already in Todoist).\n  - Update your headline, summary, and experience sections to highlight **remote work**, **AI/ML**, and **Norway-friendly skills** (e.g., English proficiency, EU citizenship).\n  - Enable the **"Open to Work"** badge with a focus on **remote/hybrid roles in Norway**.\n  - Follow **Norwegian companies** (e.g., Cognite, Vipps, Accenture Norsk, Mitigrate) and engage with their content.\n\n- **Set up and fill your Medium profile** (task in Todoist):\n  - Write 1-2 technical articles (e.g., AI/ML, Go/Python, or remote work tips) to showcase expertise.\n  - Cross-post to **Dev.to** or **Hashnode** for wider reach.\n\n- **Github cleanup** (task in Todoist: *"Tidy up my personal branding - existing Github projects"*):\n  - Update **README files** for all repos (prioritize AI/ML, Go, and Python projects).\n  - Add **clear descriptions**, **screenshots**, and **demo links** where applicable.\n  - Pin **6 most relevant projects** to your profile.\n\n- **Create a personal website** (task in Todoist: *"BRi website"*):\n  - Use a simple template (e.g., GitHub Pages, Vercel, or Netlify).\n  - Include:\n    - Resume/CV (downloadable PDF).\n    - Portfolio (link to GitHub, Medium, and key projects).\n    - Contact info (LinkedIn, email, Calendly for interviews).\n    - Blog section (link to Medium).\n  - Make it **Google-indexable** (task in Todoist: *"making the website reachable from Google"*).\n\n#### **B. Job Search Organization**\n- **Create a Notion template for job applications** (task in Todoist):\n  - Fields to include:\n    - Company name + link to job posting.\n    - Contact person/recruiter (if available).\n    - Application date + follow-up date.\n    - Status (applied, interview, rejected, etc.).\n    - Notes (salary range, tech stack, culture fit).\n    - Link to LinkedIn/Glassdoor reviews.\n  - Example: [Notion Job Tracker Template](https://www.notion.so/templates/job-application-tracker).\n\n- **Sort and tidy your job-seeking DB** (task in Todoist):\n  - Archive old/unrelevant applications.\n  - Categorize companies by **industry** (e.g., AI, SaaS, climate tech) and **location** (Oslo, remote, hybrid).\n\n- **Research Xeneta** (task in Todoist: *"Make web research about Xeneta..."*):\n  - Add them to your **Notion companies DB**.\n  - Check their careers page for openings.\n  - Look for **employee reviews** (Glassdoor, LinkedIn) and **tech stack** (e.g., Python, Go, cloud platforms).\n\n#### **C. Prepare for Remote Interviews**\n- **Complete the LinkedIn Learning course on remote interviews** (task in Todoist).\n- **Mock interview prep**:\n  - Record yourself answering common questions (e.g., *"Tell me about yourself"*, *"Why Norway?"*).\n  - Use tools like [Pramp](https://www.pramp.com/) for technical interviews.\n- **Set up a professional interview space**:\n  - Test your **camera**, **mic**, and **internet speed**.\n  - Use a **neutral background** (or virtual background).\n\n---\n\n### **2. Short-Term Priorities (2-4 Weeks)**\n#### **A. Apply Strategically**\n- **Target 5-10 companies per week**:\n  - Prioritize **Norwegian companies** from your list (e.g., Cognite, Vipps, Mitigrate, Accenture Norsk).\n  - Use **LinkedIn Jobs**, **Finn.no**, and **Nav.no** (Norwegian job portal).\n  - Set up **job alerts** for "AI Engineer," "ML Engineer," and "Backend Developer" in Norway.\n- **Tailor applications**:\n  - Customize your **resume** and **cover letter** for each role (highlight remote work, EU citizenship, and tech skills).\n  - Use [Jobscan](https://www.jobscan.co/) to optimize your resume for ATS (Applicant Tracking Systems).\n\n#### **B. Networking**\n- **Reach out to recruiters**:\n  - Message **StaffHost Digital** (recruitment agency in your list) to express interest in Norway.\n  - Connect with **Norwegian tech recruiters** on LinkedIn (search for "Tech Recruiter Norway").\n- **Join communities**:\n  - **Slack/Discord groups**: e.g., *Tech Norway*, *Oslo Tech Meetup*.\n  - **Facebook groups**: e.g., *Expats in Norway*, *Jobs in Norway for Foreigners*.\n  - **Attend virtual events**: Check [Meetup.com](https://www.meetup.com/) for Norwegian tech events.\n\n#### **C. Logistics Prep**\n- **Accommodation**:\n  - Research **short-term housing** (e.g., Airbnb, [Hybel.no](https://www.hybel.no/), [Finn.no](https://www.finn.no/)) for your first 1-3 months.\n  - Join **Facebook groups** for expat housing (e.g., *Housing in Oslo for Expats*).\n- **D-Number**:\n  - Confirm if you can apply for a **D-Number** with **20k NOK in savings** (check [UDI](https://www.udi.no/en/)).\n  - Prepare documents: passport, proof of funds, job search plan.\n- **Bank account**:\n  - Research **digital banks** (e.g., Revolut, Wise) as a temporary solution until you get a D-Number.\n  - Check if **Norwegian banks** (e.g., DNB, Nordea) allow remote account opening for EU citizens.\n\n---\n\n### **3. Mid-Term Priorities (1-3 Months)**\n#### **A. Language Learning**\n- Start **Norwegian A1 course** (task in Todoist: *"Language learning"* project).\n  - Use **Duolingo**, **Babbel**, or **FutureLearn** (free Norwegian courses).\n  - Learn **basic phrases** for job interviews (e.g., *"Jeg snakker litt norsk"* = "I speak a little Norwegian").\n\n#### **B. Moving Logistics**\n- **Health insurance**:\n  - Check if your **French/EU health insurance** covers you temporarily in Norway.\n  - Research **private insurance** (e.g., [Gjensidige](https://www.gjensidige.no/)) for long-term stays.\n- **Transport**:\n  - Compare **public transport passes** (Oslo: [Ruter](https://ruter.no/en/)).\n  - Decide if you need a **car** (check [Finn.no](https://www.finn.no/) for used cars).\n- **Budget**:\n  - Use a **cost-of-living calculator** (e.g., [Numbeo](https://www.numbeo.com/cost-of-living/in/Oslo)) to estimate expenses.\n  - Plan for **deposit + 3 months’ rent** upfront (~50,000-80,000 NOK).\n\n#### **C. Follow-Ups**\n- **Track applications** in Notion and follow up after **1-2 weeks** if no response.\n- **Reach out to connections** at target companies (e.g., *"I applied for X role and would love to learn more about your experience at Y"*).\n\n---\n\n### **4. Long-Term Priorities (3-6 Months)**\n- **Permanent residency**:\n  - After **6 months of job searching**, you can apply for a **residence permit** as a job seeker (check [UDI](https://www.udi.no/en/)).\n- **Taxes**:\n  - Register with the **Norwegian Tax Administration** ([Skatteetaten](https://www.skatteetaten.no/en/)) once you have a job.\n- **Integration**:\n  - Join **local meetups** (e.g., [Oslo Tech Meetup](https://www.meetup.com/oslo-tech-meetup/)).\n  - Take **Norwegian language classes** (B1 level for permanent residency).\n\n---\n\n### **Key Resources to Bookmark**\n1. **Job Portals**:\n   - [Finn.no](https://www.finn.no/job) (Norway’s biggest job site).\n   - [Nav.no](https://www.nav.no/en/home) (Norwegian Labour and Welfare Administration).\n   - [LinkedIn Jobs](https://www.linkedin.com/jobs/) (filter by "Norway").\n2. **Housing**:\n   - [Hybel.no](https://www.hybel.no/) (student/short-term housing).\n   - [Finn.no](https://www.finn.no/realestate/lettings/search.html) (long-term rentals).\n3. **Immigration**:\n   - [UDI](https://www.udi.no/en/) (Norwegian Directorate of Immigration).\n   - [Expat.com Norway](https://www.expat.com/forum/viewforum.php?id=103).\n4. **Cost of Living**:\n   - [Numbeo Oslo](https://www.numbeo.com/cost-of-living/in/Oslo).\n\n---\n### **Next Actions**\n1. **Today**:\n   - Update LinkedIn (skills, "Open to Work" badge).\n   - Set up Medium profile and draft 1 article.\n   - Create Notion job tracker template.\n2. **This Week**:\n   - Research Xeneta and add to Notion DB.\n   - Apply to **5 jobs** (prioritize Cognite, Vipps, Mitigrate).\n   - Message **2 recruiters** on LinkedIn.\n3. **This Month**:\n   - Start Norwegian A1 course.\n   - Research short-term housing in Oslo.\n   - Test remote interview setup.\n\n---\n### **Tools to Use**\n- **Job Tracking**: Notion, Trello, or [Huntr](https://huntr.co/).\n- **Resume Optimization**: [Jobscan](https://www.jobscan.co/), [Canva](https://www.canva.com/resume/templates/).\n- **Networking**: LinkedIn, [Meetup.com](https://www.meetup.com/).\n- **Language Learning**: Duolingo, Babbel, [FutureLearn](https://www.futurelearn.com/).', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 11403, 'total_tokens': 13767, 'completion_tokens': 2364, 'prompt_tokens_details': {'cached_tokens': 9904}}, 'model_name': 'mistral-large-latest', 'model': 'mistral-large-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019cf7d7-5e37-7e51-a5dd-41fccbb82396-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11403, 'output_tokens': 2364, 'total_tokens': 13767})]}}

""")
# Out:
# {'model': {'messages': [AIMessage(content='Based on your **Todoist tasks**, **Notion notes**, and **job-seeking progress**, here are the **next prioritized steps** for your move and job search in Norway:
#
# ---
#
# ### **1. Immediate Priorities (1-2 Weeks)**
# #### **A. Personal Branding & Visibility (Critical for Job Search)**
# - **Complete LinkedIn optimization**:
#   - List all skills on LinkedIn (task already in Todoist).
#   - Update your headline, summary, and experience sections to highlight **remote work**, **AI/ML**, and **Norway-friendly skills** (e.g., English proficiency, EU citizenship).
#   - Enable the **"Open to Work"** badge with a focus on **remote/hybrid roles in Norway**.
#   - Follow **Norwegian companies** (e.g., Cognite, Vipps, Accenture Norsk, Mitigrate) and engage with their content.
#
# - **Set up and fill your Medium profile** (task in Todoist):
#   - Write 1-2 technical articles (e.g., AI/ML, Go/Python, or remote work tips) to showcase expertise.
# ...

# %%
def _get_title(properties: dict) -> str:
    try:
        for prop_name, prop_data in properties.items():
            if prop_data["type"] == "title":
                return prop_data["title"][0]["text"]["content"]
    except KeyError as e:
        print(f"No title found: KeyError({e})")
    return ""


def search_pages(query: str, max_pages: int = 10) -> list[dict]:
    response = notion.search(
        query=query,
        page_size=max_pages,
        filter={
            "property": "object",
            "value": "page",
        },
        sort={
            "timestamp": "last_edited_time",
            "direction": "descending",
        },
    )
    results = response["results"]
    return [
        {
            "page_id": res["id"],
            "created_at": res["created_time"],
            "updated_at": res["last_edited_time"],
            "title": _get_title(res["properties"]),
        }
        for res
        in results
    ]
search_pages("ai engineer", 2)
# Out:
# [{'page_id': '30e3f60a-f4f9-8096-be3d-e60d7a28e11b',
#   'created_at': '2026-02-21T21:12:00.000Z',
#   'updated_at': '2026-03-10T10:14:00.000Z',
#   'title': 'AI Engineer'},
#  {'page_id': '2c43f60a-f4f9-801d-a59c-edfdee14fa61',
#   'created_at': '2025-12-09T11:59:00.000Z',
#   'updated_at': '2026-03-09T22:05:00.000Z',
#   'title': 'AI/ML Engineer - ATLAS AI'}]

# %%
def _read_content(content_data: dict) -> str:
    match content_data["type"]:
        case "text":
            return content_data["text"]["content"]
        case "equation":
            return content_data["equation"]["expression"]
        case "link_preview":
            return content_data["link_preview"]["url"]
        case "file":
            return content_data["file"]["url"]
        case "image":
            return content_data["image"]["url"]

def _extract_from_rich_text(block_data: dict) -> str:
    rich_text = block_data["rich_text"]
    if not rich_text:
        return ""
    return "\n".join([_read_content(text_content) for text_content in rich_text])


def _get_block_content(block: dict) -> str:
    match block["type"]:
        case "paragraph":
            return _extract_from_rich_text(block["paragraph"])
        case "heading_1":
            return f"# {_extract_from_rich_text(block["heading_1"])}"
        case "heading_2":
            return f"## {_extract_from_rich_text(block['heading_2'])}"
        case "heading_3":
            return f"### {_extract_from_rich_text(block['heading_3'])}"
        case "bulleted_list_item":
            return f"- {_extract_from_rich_text(block['bulleted_list_item'])}"
        case "numbered_list_item":
            return block["numbered_list_item"]["text"][0]["plain_text"]
        case "to_do":
            return block["to_do"]["text"][0]["plain_text"]
    return ""

def get_page_content(page_id: str) -> str:
    response = notion.blocks.children.list(block_id=page_id)
    contents = [_get_block_content(block) for block in response["results"]]
    return "\n".join(contents)





print(get_page_content("30e3f60a-f4f9-8096-be3d-e60d7a28e11b"))
# Out:
# # Analysis
# ## Keywords
# - design, build, and operate
# - reliable, observable services
# - assistants, tools, and automated workflows
# - RAG and agent-based systems
# - Migrate prototypes
# - evaluation, regression testing
# - security and governance
# - code assistant workflows.
# - collaboration with User Experience and Product Management
# requirements:
# - Software Development
# - LLM applications, retrieval systems, and tool/agent
# - hands-on
# - Python
# - TS
# - API development
# - vector search
# - prompt engineering
# - evaluation tooling
# - problem-solving
# - work collaboratively
# - English
# - explain complex technical concepts to non-technical
#
# Challenges:
# - levrage AI in a sustainable way
#
#
# ## S/W
#
#
# ## Key expectations
# - production oriented
# - security and reliability
# - API dev
#
# ## What could make a big difference
# - communication with non-tech
#
#
# # Cover letter
# ## V3 (no-AI)
#
# Dear StormGeo Team,
# ...

# %%
notion.blocks.children.list(block_id="30e3f60a-f4f9-8096-be3d-e60d7a28e11b")
# Out:
# {'object': 'list',
#  'results': [{'object': 'block',
#    'id': '30e3f60a-f4f9-80c0-889a-fcab5c65e259',
#    'parent': {'type': 'page_id',
#     'page_id': '30e3f60a-f4f9-8096-be3d-e60d7a28e11b'},
#    'created_time': '2026-02-21T21:13:00.000Z',
#    'last_edited_time': '2026-02-21T21:13:00.000Z',
#    'created_by': {'object': 'user',
#     'id': 'ca188b63-0019-4d86-890d-d314419b015d'},
#    'last_edited_by': {'object': 'user',
#     'id': 'ca188b63-0019-4d86-890d-d314419b015d'},
#    'has_children': False,
#    'in_trash': False,
#    'type': 'paragraph',
#    'paragraph': {'rich_text': [], 'color': 'default'},
#    'archived': False},
#   {'object': 'block',
#    'id': '30e3f60a-f4f9-80b1-b235-cdf8fdf0098d',
#    'parent': {'type': 'page_id',
#     'page_id': '30e3f60a-f4f9-8096-be3d-e60d7a28e11b'},
#    'created_time': '2026-02-21T21:13:00.000Z',
#    'last_edited_time': '2026-02-21T21:13:00.000Z',
#    'created_by': {'object': 'user',
# ...

# %%
def get_page_by_id(page_id: str) -> str:
    page = notion.pages.retrieve(page_id=page_id)
    return page

get_page_by_id("358b8e48-b0e5-4e7c-90cc-6f8d8586104b")
# Out:
# {'object': 'page',
#  'id': '358b8e48-b0e5-4e7c-90cc-6f8d8586104b',
#  'created_time': '2024-07-03T21:36:00.000Z',
#  'last_edited_time': '2026-03-08T21:41:00.000Z',
#  'created_by': {'object': 'user',
#   'id': 'ca188b63-0019-4d86-890d-d314419b015d'},
#  'last_edited_by': {'object': 'user',
#   'id': 'ca188b63-0019-4d86-890d-d314419b015d'},
#  'cover': {'type': 'external',
#   'external': {'url': 'https://images.unsplash.com/photo-1432821596592-e2c18b78144f?ixlib=rb-4.0.3&q=85&fm=jpg&crop=entropy&cs=srgb'}},
#  'icon': {'type': 'emoji', 'emoji': '✍️'},
#  'parent': {'type': 'data_source_id',
#   'data_source_id': '03663898-853c-403e-89ca-abafb6152dc2',
#   'database_id': '108b9bef-b6bb-4313-9443-3e8bbd47c0c5'},
#  'in_trash': False,
#  'is_locked': False,
#  'properties': {'Archivé': {'id': '%40%5CEb',
#    'type': 'checkbox',
#    'checkbox': False},
#   'URL': {'id': '%60%3BBv', 'type': 'url', 'url': None},
#   'Date de création': {'id': '%60JKu',
#    'type': 'created_time',
# ...

# %%
list(labels)

# %%
def get_todoist_structure_tree() -> dict:
    projects_paginator = todoist.get_projects()
    projects = [p for page in projects_paginator for p in page]
    # Create a dictionary of nodes by id
    nodes = {p.id: {"id": p.id, "name": p.name, "children": []} for p in projects}

    # The root node
    root = {"id": "root", "name": "/", "children": []}

    labels = todoist.get_labels(limit=100)

    # Link nodes to their parents
    for p in projects:
        node = nodes[p.id]
        if p.parent_id:
            # Check if parent exists in our nodes list (it should)
            if p.parent_id in nodes:
                nodes[p.parent_id]["children"].append(node)
            else:
                # If parent_id is set but not found, attach to root as fallback
                root["children"].append(node)
        else:
            root["children"].append(node)

    return {
        "projects_tree": root,
        "labels": [l.name for l in list(labels)[0]]
    }
get_todoist_structure_tree()
# Out:
# {'projects_tree': {'id': 'root',
#   'name': '/',
#   'children': [{'id': '6fqjjm3qr55FMF7c',
#     'name': 'Norway - 4h',
#     'children': [{'id': '6fqjjm589V3qR3JJ',
#       'name': 'Job seeking',
#       'children': [{'id': '6fqxgwRcjpXXQRJ2',
#         'name': 'Personal branding',
#         'children': []}]},
#      {'id': '6fqjjm89HJPhX37c', 'name': 'Language learning', 'children': []},
#      {'id': '6fqjjm83FxjH2wHF', 'name': 'Moving', 'children': []}]},
#    {'id': '6CrfM9Hx3rh3F6JC', 'name': 'Inbox', 'children': []},
#    {'id': '6fqjjm7QpvR86FVW',
#     'name': 'Dev / articles - 2h',
#     'children': [{'id': '6fqm3JGWh27MGw6m',
#       'name': 'S3 Box (Go)',
#       'children': []},
#      {'id': '6fqm3PWGh6RpfWjm',
#       'name': 'Genkit & Mistral (Go)',
#       'children': []},
#      {'id': '6g4HWRXJ8h6VfPfh',
#       'name': 'AI & Langchain (py)',
#       'children': []}]},
#    {'id': '6fqjjmFcvJ5WQm9J',
#     'name': 'Housework / Dog - 1h',
# ...

# %%
tasks = todoist.get_tasks(project_id="6fqm3JGWh27MGw6m")
tasks = [
    {
        "title": task.content,
        "labels": task.labels,
    }
    for task
    in list(tasks)[0]]

# tasks = list(tasks)[0]
tasks
# Out:
# [{'title': 'Wrap the write operation (while saving a file in the editor) in a goroutine, display the progress bar and block other saves meanwhile',
#   'labels': []},
#  {'title': 'disable action buttons during a loading (in directory details)',
#   'labels': []},
#  {'title': 'Refresh all information displayed on the file details widget when a file is edited (right after save)',
#   'labels': []},
#  {'title': 'Display the correct information on the file details widget for a new empty file',
#   'labels': []},
#  {'title': 'Create a Windows release', 'labels': []},
#  {'title': 'Add windows packaging to the CD',
#   'labels': ['💻 Flying laptop (opt)']},
#  {'title': 'Create a new release and fix problems if needed',
#   'labels': ['💻 Flying laptop (opt)']},
#  {'title': 'Test the release on the Windows PC',
#   'labels': ['🍔 Quick', '🏡 At home (req)']},
#  {'title': 'Use the new file object interface for file uploading and then remove the old Content struct',
#   'labels': []},
# ...
